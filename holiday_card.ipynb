# %%
import pygame
pygame.init()
from pygame import mixer

WHITE=(255,255,255)
GREEN=(0,150,0)
BLUE=(0,0,225)
RED=(150,0,0)
surface=pygame.display.set_mode((500,400))

surface.fill(GREEN)

pygame.display.set_caption("Holiday Card")

font=pygame.font.Font('freesansbold.ttf', 36)

#text surface
title_text=font.render("Happy Holidays!", True, RED,)


textRect=text.get_rect()
X=500 # set x-axis location
y=200 # set y-axis location
textRect.center=(X//2,y//2)



#Left, top, width, and height
pygame.draw.rect(surface, WHITE, pygame.Rect(0,350,500,50))

img=pygame.image.load("snowman.jpg", "candycane.jpg")

x=275 # X coordinate of the image
y=210 # Y coordinate of the image




surface.blit(resized_image, (x,y))


mixer.init()
mixer.music.load("christmasTwinkle.mp3")
mixer.music.set_volume(0.7)
mixer.music.play()
pygame.display.flip()

active=True
while active:
    
    surface.blit(text, textRect)
    
    for event in pygame.event.get():
        if event.type==pygame.QUIT:
            active=False
    pygame.display.update()
    
pygame.quit()
